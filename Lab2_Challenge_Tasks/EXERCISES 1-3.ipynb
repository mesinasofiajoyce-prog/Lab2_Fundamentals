# %%
# Extract first letter of engineer name
engineer_name = "ENGINEER OLIS"
first_letter = engineer_name[0]

# Convert to ASCII
ascii_value = ord(first_letter)

# Seed number and total loops
seed_num = 6
loops = 9

# Calculate verification hash
verification_hash = (ascii_value * seed_num) - loops

# Display results
print("First letter:", first_letter)
print("ASCII value:", ascii_value)
print("Verification hash:", verification_hash)
# Out:
# First letter: E
# ASCII value: 69
# Verification hash: 405

# %%
# Initialize variables
target_name = "OLIS"  # replace with your surname, e.g., "Garcia"
seed_num = 6           # replace with the last digit of your student ID
redacted_name = ""

# Process each character in target_name
for char in target_name:
    if char.lower() in "aeiou":  # example condition: redact vowels
        redacted_name += "*"
    else:
        redacted_name += char

# Output the result
print("Original Name: ", target_name)
print("Redacted Name: ", redacted_name)
# Out:
# Original Name:  OLIS
# Redacted Name:  *L*S

# %%
# Initialize variables
correct_password = "yumiko123"
attempt_counter = 0

# Simulated password attempts (replace or extend as needed)
user_attempts = ["wrongpass", "1234", "yumiko123"]

# Process each attempt
for user_password in user_attempts:
    if user_password != correct_password:
        attempt_counter += 1
        print(f"Incorrect password: {user_password}")
    else:
        print(f"Access granted with password: {user_password}")
        break

# Display the total number of incorrect attempts
print("Number of incorrect attempts:", attempt_counter)
# Out:
# Incorrect password: wrongpass
# Incorrect password: 1234
# Access granted with password: yumiko123
# Number of incorrect attempts: 2
